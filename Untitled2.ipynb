# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
child = pd.read_excel('assignment_data.xlsx')
trainers = pd.read_excel('Trainers.xlsx')
booked = pd.read_excel('Booked_Users.xlsx')
subs = pd.read_excel('Subscrption.xlsx')
trainers
# Out:
#     Trainer Name               Date              Timing       Grade  \
# 0       FAC_5001  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 1       FAC_5002  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 2       FAC_5003  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 3       FAC_5006  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 4       FAC_5007  16 April Thursday        4:00-4:45 pm  Grade 3,4
# ..           ...                ...                 ...         ...
# 169     FAC_5009    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 170     FAC_5040    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 171     FAC_5038    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 172     FAC_5002    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 173     FAC_5022    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
#
#     Batch size   Batch count      Batch                  Topics
# 0         group          9.0    trial I     Rocking with rhymes
# ...

# %%
trainers['Date'] = trainers['Date'].str[:2]
trainers
# Out:
#     Trainer Name Date              Timing       Grade Batch size   \
# 0       FAC_5001   16  11.15 am - 12 noon   Grade 1,2       group
# 1       FAC_5002   16  11.15 am - 12 noon  Grade 3,4        group
# 2       FAC_5003   16  11.15 am - 12 noon   Grade 1,2       group
# 3       FAC_5006   16  11.15 am - 12 noon  Grade 3,4        group
# 4       FAC_5007   16        4:00-4:45 pm  Grade 3,4        group
# ..           ...  ...                 ...         ...         ...
# 169     FAC_5009   27  6.00 pm - 6.45 pm    Grade 3,4         NaN
# 170     FAC_5040   27  6.00 pm - 6.45 pm    Grade 1,2         NaN
# 171     FAC_5038   27  6.00 pm - 6.45 pm    Grade 3,4         NaN
# 172     FAC_5002   27  6.00 pm - 6.45 pm    Grade 1,2         NaN
# 173     FAC_5022   27  6.00 pm - 6.45 pm    Grade 1,2         NaN
#
#      Batch count      Batch                  Topics
# 0            9.0    trial I     Rocking with rhymes
# 1            9.0    trial I        In my mind's eye
# ...

# %%
booked = pd.read_excel('Booked_Users.xlsx')

# %%
display(trainers)
display(subs)
display(booked)
# Out:
#     Trainer Name               Date              Timing       Grade  \
# 0       FAC_5001  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 1       FAC_5002  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 2       FAC_5003  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 3       FAC_5006  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 4       FAC_5007  16 April Thursday        4:00-4:45 pm  Grade 3,4
# ..           ...                ...                 ...         ...
# 169     FAC_5009    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 170     FAC_5040    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 171     FAC_5038    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 172     FAC_5002    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 173     FAC_5022    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
#
#     Batch size   Batch count      Batch                  Topics
# 0         group          9.0    trial I     Rocking with rhymes
# ...

# %%
booked['Opted Start Date'] = booked['Opted Start Time'].str[:2]

# %%
booked
# Out:
#           Invitee UUID                                              Batch  \
# 0     AGIV7AYTBF4ZA6SA  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 1     HAPQZDZXDJPMFZ73  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 2     AHLT5B5XGJTONPE3  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 3     HCNR5B2SFMSX727O  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
# 4     BFIT2F3UDJ5MV5GT  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
# ...                ...                                                ...
# 1706  BBJSY3OJTAA54LMV  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1707  FHMX5ZJKVGJOUQTF  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1708  DHMW43JNVC5SDZ6D  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1709  ACIW47ILSKFJ2WPS  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1710  GANT23JJWJNWRGUH  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
#
#          Enrolment Type Child Name    Grade  \
# ...

# %%
booked['Opted Start Time'] = booked['Opted Start Time'].str[-8:-3]
booked
# Out:
#           Invitee UUID                                              Batch  \
# 0     AGIV7AYTBF4ZA6SA  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 1     HAPQZDZXDJPMFZ73  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 2     AHLT5B5XGJTONPE3  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 3     HCNR5B2SFMSX727O  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
# 4     BFIT2F3UDJ5MV5GT  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
# ...                ...                                                ...
# 1706  BBJSY3OJTAA54LMV  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1707  FHMX5ZJKVGJOUQTF  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1708  DHMW43JNVC5SDZ6D  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1709  ACIW47ILSKFJ2WPS  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1710  GANT23JJWJNWRGUH  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
#
#          Enrolment Type Child Name    Grade  \
# ...

# %%
trainers['time_upper'] = trainers['Timing'].str[:5]
trainers['time_lower'] = trainers['Timing'].str[-8:-2]

# %%
trainers['Date'] = trainers['Date'].str[:2]
trainers
# Out:
#     Trainer Name Date              Timing       Grade Batch size   \
# 0       FAC_5001   16  11.15 am - 12 noon   Grade 1,2       group
# 1       FAC_5002   16  11.15 am - 12 noon  Grade 3,4        group
# 2       FAC_5003   16  11.15 am - 12 noon   Grade 1,2       group
# 3       FAC_5006   16  11.15 am - 12 noon  Grade 3,4        group
# 4       FAC_5007   16        4:00-4:45 pm  Grade 3,4        group
# ..           ...  ...                 ...         ...         ...
# 169     FAC_5009   27  6.00 pm - 6.45 pm    Grade 3,4         NaN
# 170     FAC_5040   27  6.00 pm - 6.45 pm    Grade 1,2         NaN
# 171     FAC_5038   27  6.00 pm - 6.45 pm    Grade 3,4         NaN
# 172     FAC_5002   27  6.00 pm - 6.45 pm    Grade 1,2         NaN
# 173     FAC_5022   27  6.00 pm - 6.45 pm    Grade 1,2         NaN
#
#      Batch count      Batch                  Topics time_upper time_lower
# 0            9.0    trial I     Rocking with rhymes      11.15      12 no
# ...

# %%
display(booked)
display(trainers)
display(subs)
# Out:
#           Invitee UUID                                              Batch  \
# 0     AGIV7AYTBF4ZA6SA  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 1     HAPQZDZXDJPMFZ73  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 2     AHLT5B5XGJTONPE3  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 3     HCNR5B2SFMSX727O  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
# 4     BFIT2F3UDJ5MV5GT  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
# ...                ...                                                ...
# 1706  BBJSY3OJTAA54LMV  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1707  FHMX5ZJKVGJOUQTF  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1708  DHMW43JNVC5SDZ6D  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1709  ACIW47ILSKFJ2WPS  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
# 1710  GANT23JJWJNWRGUH  fREADom Trial - Grades 1,2 [III] 06:00pm - Mon...
#
#          Enrolment Type Child Name    Grade  \
# ...
